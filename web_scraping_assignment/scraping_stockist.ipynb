# %% [markdown]
# # Scraping other Stockist Sites

# %%
import time
import os
import json
import sys
import csv
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

#sys.version

# %%
zipsTop500 = [
    94123, 19104, 77494,90011, 75034,60629,11211,
    77449,75070,79936,11368,77084,11385,90650,8701,91331,11208,78660,10467,90201,90044,10473,92507,11216,92324,
    92335,37013,11236,92336,94565,11373,11226,77479,90250,90805,90280,60618,91342,77433,75052,30044,92503,10025,77584,
    29483,77573,11207,92683,11220,77429,91710,10456,11214,11234,10314,92154,78521,926,91911,60639,30043,92804,11219,
    11206,11230,75217,92376,60632,93307,92592,92704,10458,93722,11746,33027,11435,78520,78586,93117,95355,23320,
    60647,11221,94112,93033,93727,95076,78613,92345,91744,79938,92126,91709,66062,77379,92509,60617,22193,11377,11229,
    78666,99301,60804,11355,27610,91335,95823,78542,37042,30024,11223,75035,78572,60608,79912,11233,78130,95630,725,
    28269,10453,60625,76244,10468,47906,78577,94533,78641,94544,77083,75211,60623,87121,23464,11203,85142,11235,77459,
    76063,91706,78245,90706,96706,92105,11204,77450,33311,33024, 94080,84015,75067,19111,95624,94558,43123,7305,30004,
    30349,93550,60634,93257,10462,95035,75228,89108,37211,93274,94587,63376,93535,33023,91730,34787,92882,10457,10029,
    33012,92805,33411,94536,10466,90255,10452,10002,93306,80013,19120,97701,91910,97006,90003,92553,33647,11212,77095,
    75002,84095,85364,27587,11218,85032,33025,22191,30040,94110,34953,11375,92880,10469,76028,60614,45011,73099,98052,
    93065,97007,19124,80219,30041,78046,30127,60505,97229,92563,60085,91766,92021,84118,80134,953,89110,91402,96797,
    60641,30281,98012,95123,11215,32828,92114,7055,85204,85225,87114,60640,20011,75068,30052,33186,90262,94509,85281,
    85301,77036,20002,30022,95687,76179,89031,78596,93230,60620,77845,90631,30047,21234,93536,30096,28027,95747,11691,
    11209,37075,75243,83646,7087,10472,78045,23462,33015,92407,30135,90026,11706,84043,11213,90037,48197,94538,33157,
    92703,89115,89121,94541,99654,90022,30331,95758,78251,32218,85308,20019,92801,66061,95206,43081,92677,94513,91343,
    23322,94015,92562,7002,17603,77072,60628,92201,38401,29681,11201,10027,10977,85041,94501,87120,85033,28215,11432,
    84404,14850,29072,33463,7093,46307,32822,28078,2301,30062,20147,30188,91762,32765,77346,98682,92115,8753,93906,
    60651,78664,94806,20878,95020,44256,43026,85326,40475,92346,78745, 60657,20906,10463,80015,6902,28277,19720,10024,
    91977,92404,95127,44035,91770,11372,85008,89123,78574,78250,33313,19143,11717,90640,90019,91950,75071,27406,60402,
    75043,42101,92707,11434,90660,32210,92627,92504,11210,77373,79928,95608,77396,10023,43055,43130,78640,78240,77077,
    75150,60073,74012,80634,78249,93905,19134,75040,95014,92647,91702,78228,77407,60619,10701,94122,30058,73160,32244,
    34711,95111,78504,7047,37167,48180,78254,10312,90004,91732,53215,32818,37122,21740,91761,90731,92630,2360,30263,
    2148,77521,75227,34744, 29445,95051,93312,92057,28314,95828,33458,72401,30144,30083,33511,33142,77840,75056,
    956,60609,2155,37129,90042,33414,32808,83709,29485,92570,33125,78501,10031,37064,20874,32825,77386,22030,30906,
    77375,72712,85122,6010,37128,78753,76137,95112,33064,96818,44060,43230,93030,79924,22407,10032,76010,92571,
    22192,21122,21117,60016
]

zipsShortList = zipsTop500[0:8]

# %% [markdown]
# ### Obey

# %%
stockist_urls = [
    'https://www.markcross.com/pages/location',
    'https://www.jlaudio.com/pages/dealer-locator',
    'https://obeyclothing.com/pages/stockists',
    'https://www.rocskincare.com/pages/store-locator',
    'https://www.hurley.com/pages/store-locator',
    'https://lespecs.com/pages/stockists',
    'https://ullajohnson.com/pages/store-locator'
    #'https://www.morphe.com/pages/store-locator',
    #'https://stockist.co/demo'

]

# %%
mark_lespecs = [
    'https://www.markcross.com/pages/location',
    'https://lespecs.com/pages/stockists'
]

# %% [markdown]
# #### Notes
# * Stockist demo was sometimes werid
# * Stetson didn't work
#     * 'https://stetson.com/pages/store-locator'

# %%
url = stockist_urls[0]
webName = url.split('.co')[0].split('//')[1].replace('.', '').replace('www', '')
#browser.get(url) #Get the link

# %%
chrome_options = Options()
chrome_options.add_argument("--headless") # Ensure GUI is off
chrome_options.add_argument("--no-sandbox")

browser = webdriver.Chrome(options=chrome_options) #Chrome() Safari

# %%
browser.get(url) #Get the link
time.sleep(2) #wait for pop-up
browser.get(url) #Pop up protection

# %%
#results = {}
resultsList = []

for link in mark_lespecs: #stockist_urls:
    url = link
    webName = url.split('.co')[0].split('//')[1].replace('.', '').replace('www', '')
    browser.get(url)
    print(webName)

    for i, zipcode in enumerate(zipsTop500, start=1):
        browser.get(url)
        try:
            query_entry=browser.find_element(By.CLASS_NAME, 'stockist-query-entry')
            input_field = query_entry.find_element(By.TAG_NAME, 'input')
            submit = query_entry.find_element(By.CLASS_NAME, 'stockist-search-button').find_element(By.TAG_NAME, 'button')

            input_field.clear()
            input_field.send_keys(zipcode)
            submit.click()

            time.sleep(2)
            search_results = browser.find_element(By.CLASS_NAME, 'stockist-result-list')
            res=search_results.find_elements(By.CLASS_NAME,'stockist-result')
            
            for store in res:
                storeInfo = {}

                storeInfo['name'] = store.find_element(By.CLASS_NAME, 'stockist-result-name').get_attribute("textContent")
                address = [line.get_attribute("textContent") for line in 
                          store.find_element(By.CLASS_NAME, 'stockist-result-address').find_elements(By.TAG_NAME, 'div')]
                storeInfo['address'] = ", ".join(address)
                storeInfo['distance'] = store.find_element(By.CLASS_NAME, 'stockist-result-distance-text').get_attribute("textContent")
                storeInfo['google_maps'] = store.find_element(By.CLASS_NAME, 'stockist-result-directions-link').find_element(By.TAG_NAME, 'a').get_attribute('href')
                storeInfo['zipcode'] = zipcode
                storeInfo['brand'] = webName
                try:
                    storeInfo['website_link'] = store.find_element(By.CLASS_NAME, 'stockist-result-website').find_element(By.TAG_NAME, 'a').get_attribute('href')
                    print(storeInfo['website_link'])
                except:
                    print('...no weblink', storeInfo['name'], zipcode)
                resultsList.append(storeInfo)
                #results[webName].append(storeInfo)
            print(zipcode, " results:", len(res), ' -', i)
        except:
            browser.get(url)
            time.sleep(2)
            print("timeout/error", zipcode, i)

print("===Done===")
# Out:
# markcross
# https://elysewalker.com/
# 94123  results: 1  - 1
# ...no weblink L'Apartment 19104
# https://elysewalker.com/
# https://fivestoryny.com/
# 19104  results: 3  - 2
# ...no weblink Forty Five Ten 77494
# ...no weblink Forty Five Ten 77494
# ...no weblink Market Highland Park Village 77494
# 77494  results: 3  - 3
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90011  results: 4  - 4
# ...no weblink Forty Five Ten 75034
# ...no weblink Market Highland Park Village 75034
# ...no weblink Forty Five Ten 75034
# 75034  results: 3  - 5
# 60629  results: 0  - 6
# ...no weblink L'Apartment 11211
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11211
# 11211  results: 4  - 7
# ...no weblink Forty Five Ten 77449
# ...no weblink Forty Five Ten 77449
# ...no weblink Market Highland Park Village 77449
# 77449  results: 3  - 8
# ...no weblink Forty Five Ten 75070
# ...no weblink Market Highland Park Village 75070
# ...no weblink Forty Five Ten 75070
# 75070  results: 3  - 9
# 79936  results: 0  - 10
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 11368
# ...no weblink VRSNL 11368
# 11368  results: 4  - 11
# ...no weblink Forty Five Ten 77084
# ...no weblink Forty Five Ten 77084
# ...no weblink Market Highland Park Village 77084
# 77084  results: 3  - 12
# ...no weblink L'Apartment 11385
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11385
# 11385  results: 4  - 13
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90650  results: 4  - 14
# timeout/error 8701 15
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91331  results: 4  - 16
# ...no weblink L'Apartment 11208
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11208
# 11208  results: 4  - 17
# ...no weblink Forty Five Ten 78660
# ...no weblink Forty Five Ten 78660
# ...no weblink Market Highland Park Village 78660
# 78660  results: 3  - 18
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10467
# ...no weblink VRSNL 10467
# 10467  results: 4  - 19
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90201  results: 4  - 20
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90044  results: 4  - 21
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10473
# ...no weblink VRSNL 10473
# 10473  results: 4  - 22
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92507  results: 4  - 23
# ...no weblink L'Apartment 11216
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11216
# 11216  results: 4  - 24
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92324  results: 4  - 25
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92335  results: 4  - 26
# 37013  results: 0  - 27
# ...no weblink L'Apartment 11236
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11236
# 11236  results: 4  - 28
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92336  results: 4  - 29
# https://elysewalker.com/
# 94565  results: 1  - 30
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 11373
# ...no weblink VRSNL 11373
# 11373  results: 4  - 31
# ...no weblink L'Apartment 11226
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11226
# 11226  results: 4  - 32
# ...no weblink Forty Five Ten 77479
# ...no weblink Forty Five Ten 77479
# ...no weblink Market Highland Park Village 77479
# 77479  results: 3  - 33
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90250  results: 4  - 34
# timeout/error 90805 35
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90280  results: 4  - 36
# 60618  results: 0  - 37
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91342  results: 4  - 38
# ...no weblink Forty Five Ten 77433
# ...no weblink Forty Five Ten 77433
# ...no weblink Market Highland Park Village 77433
# 77433  results: 3  - 39
# ...no weblink Forty Five Ten 75052
# ...no weblink Forty Five Ten 75052
# ...no weblink Market Highland Park Village 75052
# 75052  results: 3  - 40
# ...no weblink Capitol 30044
# 30044  results: 1  - 41
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92503  results: 4  - 42
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10025
# ...no weblink VRSNL 10025
# 10025  results: 4  - 43
# ...no weblink Forty Five Ten 77584
# ...no weblink Forty Five Ten 77584
# ...no weblink Market Highland Park Village 77584
# 77584  results: 3  - 44
# ...no weblink Capitol 29483
# 29483  results: 1  - 45
# ...no weblink Forty Five Ten 77573
# 77573  results: 1  - 46
# ...no weblink L'Apartment 11207
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11207
# 11207  results: 4  - 47
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92683  results: 4  - 48
# ...no weblink L'Apartment 11220
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11220
# 11220  results: 4  - 49
# ...no weblink Forty Five Ten 77429
# ...no weblink Forty Five Ten 77429
# ...no weblink Market Highland Park Village 77429
# 77429  results: 3  - 50
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91710  results: 4  - 51
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10456
# ...no weblink VRSNL 10456
# 10456  results: 4  - 52
# ...no weblink L'Apartment 11214
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11214
# 11214  results: 4  - 53
# ...no weblink L'Apartment 11234
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11234
# 11234  results: 4  - 54
# ...no weblink L'Apartment 10314
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 10314
# 10314  results: 4  - 55
# timeout/error 92154 56
# 78521  results: 0  - 57
# 926  results: 0  - 58
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91911  results: 4  - 59
# 60639  results: 0  - 60
# ...no weblink Capitol 30043
# 30043  results: 1  - 61
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92804  results: 4  - 62
# ...no weblink L'Apartment 11219
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11219
# 11219  results: 4  - 63
# ...no weblink L'Apartment 11206
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11206
# 11206  results: 4  - 64
# ...no weblink L'Apartment 11230
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11230
# 11230  results: 4  - 65
# ...no weblink Forty Five Ten 75217
# ...no weblink Forty Five Ten 75217
# ...no weblink Market Highland Park Village 75217
# 75217  results: 3  - 66
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92376  results: 4  - 67
# 60632  results: 0  - 68
# https://elysewalker.com/
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# 93307  results: 4  - 69
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92592  results: 4  - 70
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92704  results: 4  - 71
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10458
# ...no weblink VRSNL 10458
# 10458  results: 4  - 72
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# 93722  results: 5  - 73
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 11746
# ...no weblink VRSNL 11746
# 11746  results: 4  - 74
# https://marissacollections.com/
# ...no weblink Marissa Collections 33027
# 33027  results: 2  - 75
# timeout/error 11435 76
# 78520  results: 0  - 77
# 78586  results: 0  - 78
# https://elysewalker.com/
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# 93117  results: 4  - 79
# ...no weblink L'Apartment 95355
# https://elysewalker.com/
# https://fivestoryny.com/
# 95355  results: 3  - 80
# 23320  results: 0  - 81
# 60647  results: 0  - 82
# ...no weblink L'Apartment 11221
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11221
# 11221  results: 4  - 83
# https://elysewalker.com/
# 94112  results: 1  - 84
# https://elysewalker.com/
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# 93033  results: 4  - 85
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# 93727  results: 5  - 86
# https://elysewalker.com/
# 95076  results: 1  - 87
# ...no weblink Forty Five Ten 78613
# ...no weblink Forty Five Ten 78613
# ...no weblink Market Highland Park Village 78613
# 78613  results: 3  - 88
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92345  results: 4  - 89
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91744  results: 4  - 90
# 79938  results: 0  - 91
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92126  results: 4  - 92
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91709  results: 4  - 93
# 66062  results: 0  - 94
# ...no weblink Forty Five Ten 77379
# ...no weblink Forty Five Ten 77379
# ...no weblink Market Highland Park Village 77379
# 77379  results: 3  - 95
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92509  results: 4  - 96
# timeout/error 60617 97
# ...no weblink L'Apartment 22193
# https://elysewalker.com/
# https://fivestoryny.com/
# 22193  results: 3  - 98
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 11377
# ...no weblink VRSNL 11377
# 11377  results: 4  - 99
# ...no weblink L'Apartment 11229
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11229
# 11229  results: 4  - 100
# ...no weblink Forty Five Ten 78666
# ...no weblink Forty Five Ten 78666
# ...no weblink Market Highland Park Village 78666
# 78666  results: 3  - 101
# https://www.amazon.com/
# 99301  results: 1  - 102
# 60804  results: 0  - 103
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 11355
# ...no weblink VRSNL 11355
# 11355  results: 4  - 104
# ...no weblink Capitol 27610
# 27610  results: 1  - 105
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91335  results: 4  - 106
# https://elysewalker.com/
# 95823  results: 1  - 107
# 78542  results: 0  - 108
# 37042  results: 0  - 109
# ...no weblink Capitol 30024
# 30024  results: 1  - 110
# ...no weblink L'Apartment 11223
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11223
# 11223  results: 4  - 111
# ...no weblink Forty Five Ten 75035
# ...no weblink Market Highland Park Village 75035
# ...no weblink Forty Five Ten 75035
# 75035  results: 3  - 112
# 78572  results: 0  - 113
# 60608  results: 0  - 114
# 79912  results: 0  - 115
# ...no weblink L'Apartment 11233
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11233
# 11233  results: 4  - 116
# ...no weblink Forty Five Ten 78130
# ...no weblink Forty Five Ten 78130
# ...no weblink Market Highland Park Village 78130
# 78130  results: 3  - 117
# timeout/error 95630 118
# 725  results: 0  - 119
# ...no weblink Capitol 28269
# 28269  results: 1  - 120
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10453
# ...no weblink VRSNL 10453
# 10453  results: 4  - 121
# 60625  results: 0  - 122
# ...no weblink Forty Five Ten 76244
# ...no weblink Market Highland Park Village 76244
# ...no weblink Forty Five Ten 76244
# 76244  results: 3  - 123
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10468
# ...no weblink VRSNL 10468
# 10468  results: 4  - 124
# 47906  results: 0  - 125
# 78577  results: 0  - 126
# https://elysewalker.com/
# 94533  results: 1  - 127
# ...no weblink Forty Five Ten 78641
# ...no weblink Forty Five Ten 78641
# ...no weblink Market Highland Park Village 78641
# 78641  results: 3  - 128
# https://elysewalker.com/
# 94544  results: 1  - 129
# ...no weblink Forty Five Ten 77083
# ...no weblink Forty Five Ten 77083
# ...no weblink Market Highland Park Village 77083
# 77083  results: 3  - 130
# ...no weblink Forty Five Ten 75211
# ...no weblink Forty Five Ten 75211
# ...no weblink Market Highland Park Village 75211
# 75211  results: 3  - 131
# 60623  results: 0  - 132
# 87121  results: 0  - 133
# 23464  results: 0  - 134
# ...no weblink L'Apartment 11203
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11203
# 11203  results: 4  - 135
# 85142  results: 0  - 136
# ...no weblink L'Apartment 11235
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11235
# 11235  results: 4  - 137
# ...no weblink Forty Five Ten 77459
# ...no weblink Forty Five Ten 77459
# ...no weblink Market Highland Park Village 77459
# 77459  results: 3  - 138
# ...no weblink Forty Five Ten 76063
# ...no weblink Forty Five Ten 76063
# ...no weblink Market Highland Park Village 76063
# 76063  results: 3  - 139
# timeout/error 91706 140
# 78245  results: 0  - 141
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90706  results: 4  - 142
# 96706  results: 0  - 143
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92105  results: 4  - 144
# ...no weblink L'Apartment 11204
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11204
# 11204  results: 4  - 145
# ...no weblink Forty Five Ten 77450
# ...no weblink Forty Five Ten 77450
# ...no weblink Market Highland Park Village 77450
# 77450  results: 3  - 146
# https://marissacollections.com/
# ...no weblink Marissa Collections 33311
# 33311  results: 2  - 147
# https://marissacollections.com/
# ...no weblink Marissa Collections 33024
# 33024  results: 2  - 148
# https://elysewalker.com/
# 94080  results: 1  - 149
# 84015  results: 0  - 150
# ...no weblink Forty Five Ten 75067
# ...no weblink Market Highland Park Village 75067
# ...no weblink Forty Five Ten 75067
# 75067  results: 3  - 151
# ...no weblink L'Apartment 19111
# https://elysewalker.com/
# https://fivestoryny.com/
# 19111  results: 3  - 152
# https://elysewalker.com/
# 95624  results: 1  - 153
# https://elysewalker.com/
# 94558  results: 1  - 154
# 43123  results: 0  - 155
# ...no weblink L'Apartment 7305
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 7305
# 7305  results: 4  - 156
# ...no weblink Capitol 30004
# 30004  results: 1  - 157
# ...no weblink Capitol 30349
# 30349  results: 1  - 158
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 93550  results: 4  - 159
# 60634  results: 0  - 160
# timeout/error 93257 161
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10462
# ...no weblink VRSNL 10462
# 10462  results: 4  - 162
# https://elysewalker.com/
# 95035  results: 1  - 163
# ...no weblink Forty Five Ten 75228
# ...no weblink Market Highland Park Village 75228
# ...no weblink Forty Five Ten 75228
# 75228  results: 3  - 164
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 89108  results: 4  - 165
# 37211  results: 0  - 166
# https://elysewalker.com/
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 93274  results: 5  - 167
# https://elysewalker.com/
# 94587  results: 1  - 168
# 63376  results: 0  - 169
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 93535  results: 4  - 170
# https://marissacollections.com/
# ...no weblink Marissa Collections 33023
# 33023  results: 2  - 171
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91730  results: 4  - 172
# https://marissacollections.com/
# ...no weblink Marissa Collections 34787
# 34787  results: 2  - 173
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92882  results: 4  - 174
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10457
# ...no weblink VRSNL 10457
# 10457  results: 4  - 175
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10029
# ...no weblink VRSNL 10029
# 10029  results: 4  - 176
# https://marissacollections.com/
# ...no weblink Marissa Collections 33012
# 33012  results: 2  - 177
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92805  results: 4  - 178
# https://marissacollections.com/
# ...no weblink Marissa Collections 33411
# 33411  results: 2  - 179
# https://elysewalker.com/
# 94536  results: 1  - 180
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10466
# ...no weblink VRSNL 10466
# 10466  results: 4  - 181
# timeout/error 90255 182
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10452
# ...no weblink VRSNL 10452
# 10452  results: 4  - 183
# ...no weblink L'Apartment 10002
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 10002
# 10002  results: 4  - 184
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 93306  results: 4  - 185
# 80013  results: 0  - 186
# ...no weblink L'Apartment 19120
# https://elysewalker.com/
# https://fivestoryny.com/
# 19120  results: 3  - 187
# https://www.amazon.com/
# 97701  results: 1  - 188
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91910  results: 4  - 189
# https://www.amazon.com/
# 97006  results: 1  - 190
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90003  results: 4  - 191
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92553  results: 4  - 192
# ...no weblink Marissa Collections 33647
# https://marissacollections.com/
# 33647  results: 2  - 193
# ...no weblink L'Apartment 11212
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11212
# 11212  results: 4  - 194
# ...no weblink Forty Five Ten 77095
# ...no weblink Forty Five Ten 77095
# ...no weblink Market Highland Park Village 77095
# 77095  results: 3  - 195
# ...no weblink Forty Five Ten 75002
# ...no weblink Market Highland Park Village 75002
# ...no weblink Forty Five Ten 75002
# 75002  results: 3  - 196
# 84095  results: 0  - 197
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 85364  results: 4  - 198
# ...no weblink Capitol 27587
# 27587  results: 1  - 199
# ...no weblink L'Apartment 11218
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11218
# 11218  results: 4  - 200
# 85032  results: 0  - 201
# https://marissacollections.com/
# ...no weblink Marissa Collections 33025
# 33025  results: 2  - 202
# timeout/error 22191 203
# ...no weblink Capitol 30040
# 30040  results: 1  - 204
# https://elysewalker.com/
# 94110  results: 1  - 205
# https://marissacollections.com/
# ...no weblink Marissa Collections 34953
# 34953  results: 2  - 206
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 11375
# ...no weblink VRSNL 11375
# 11375  results: 4  - 207
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92880  results: 4  - 208
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10469
# ...no weblink VRSNL 10469
# 10469  results: 4  - 209
# ...no weblink Forty Five Ten 76028
# ...no weblink Forty Five Ten 76028
# ...no weblink Market Highland Park Village 76028
# 76028  results: 3  - 210
# 60614  results: 0  - 211
# 45011  results: 0  - 212
# ...no weblink Forty Five Ten 73099
# ...no weblink Market Highland Park Village 73099
# ...no weblink Forty Five Ten 73099
# 73099  results: 3  - 213
# https://www.amazon.com/
# 98052  results: 1  - 214
# https://elysewalker.com/
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# 93065  results: 4  - 215
# https://www.amazon.com/
# 97007  results: 1  - 216
# ...no weblink L'Apartment 19124
# https://elysewalker.com/
# https://fivestoryny.com/
# 19124  results: 3  - 217
# 80219  results: 0  - 218
# ...no weblink Capitol 30041
# 30041  results: 1  - 219
# 78046  results: 0  - 220
# ...no weblink Capitol 30127
# 30127  results: 1  - 221
# 60505  results: 0  - 222
# https://www.amazon.com/
# 97229  results: 1  - 223
# timeout/error 92563 224
# 60085  results: 0  - 225
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91766  results: 4  - 226
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92021  results: 4  - 227
# 84118  results: 0  - 228
# 80134  results: 0  - 229
# 953  results: 0  - 230
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 89110  results: 4  - 231
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91402  results: 4  - 232
# 96797  results: 0  - 233
# 60641  results: 0  - 234
# ...no weblink Capitol 30281
# 30281  results: 1  - 235
# https://www.amazon.com/
# 98012  results: 1  - 236
# https://elysewalker.com/
# 95123  results: 1  - 237
# ...no weblink L'Apartment 11215
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11215
# 11215  results: 4  - 238
# https://marissacollections.com/
# ...no weblink Marissa Collections 32828
# 32828  results: 2  - 239
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92114  results: 4  - 240
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 7055
# ...no weblink VRSNL 7055
# 7055  results: 4  - 241
# 85204  results: 0  - 242
# 85225  results: 0  - 243
# 87114  results: 0  - 244
# timeout/error 60640 245
# ...no weblink L'Apartment 20011
# https://elysewalker.com/
# https://fivestoryny.com/
# 20011  results: 3  - 246
# ...no weblink Forty Five Ten 75068
# ...no weblink Market Highland Park Village 75068
# ...no weblink Forty Five Ten 75068
# 75068  results: 3  - 247
# ...no weblink Capitol 30052
# 30052  results: 1  - 248
# https://marissacollections.com/
# ...no weblink Marissa Collections 33186
# 33186  results: 2  - 249
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90262  results: 4  - 250
# https://elysewalker.com/
# 94509  results: 1  - 251
# 85281  results: 0  - 252
# 85301  results: 0  - 253
# ...no weblink Forty Five Ten 77036
# ...no weblink Forty Five Ten 77036
# ...no weblink Market Highland Park Village 77036
# 77036  results: 3  - 254
# ...no weblink L'Apartment 20002
# https://elysewalker.com/
# https://fivestoryny.com/
# 20002  results: 3  - 255
# ...no weblink Capitol 30022
# 30022  results: 1  - 256
# https://elysewalker.com/
# 95687  results: 1  - 257
# ...no weblink Forty Five Ten 76179
# ...no weblink Market Highland Park Village 76179
# ...no weblink Forty Five Ten 76179
# 76179  results: 3  - 258
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 89031  results: 4  - 259
# 78596  results: 0  - 260
# https://elysewalker.com/
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 93230  results: 5  - 261
# 60620  results: 0  - 262
# ...no weblink Forty Five Ten 77845
# ...no weblink Forty Five Ten 77845
# ...no weblink Market Highland Park Village 77845
# 77845  results: 3  - 263
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90631  results: 4  - 264
# ...no weblink Capitol 30047
# 30047  results: 1  - 265
# timeout/error 21234 266
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 93536  results: 4  - 267
# ...no weblink Capitol 30096
# 30096  results: 1  - 268
# ...no weblink Capitol 28027
# 28027  results: 1  - 269
# https://elysewalker.com/
# 95747  results: 1  - 270
# ...no weblink L'Apartment 11691
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11691
# 11691  results: 4  - 271
# ...no weblink L'Apartment 11209
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11209
# 11209  results: 4  - 272
# 37075  results: 0  - 273
# ...no weblink Forty Five Ten 75243
# ...no weblink Market Highland Park Village 75243
# ...no weblink Forty Five Ten 75243
# 75243  results: 3  - 274
# 83646  results: 0  - 275
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 7087
# ...no weblink VRSNL 7087
# 7087  results: 4  - 276
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10472
# ...no weblink VRSNL 10472
# 10472  results: 4  - 277
# 78045  results: 0  - 278
# 23462  results: 0  - 279
# https://marissacollections.com/
# ...no weblink Marissa Collections 33015
# 33015  results: 2  - 280
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92407  results: 4  - 281
# ...no weblink Capitol 30135
# 30135  results: 1  - 282
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90026  results: 4  - 283
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 11706
# ...no weblink VRSNL 11706
# 11706  results: 4  - 284
# 84043  results: 0  - 285
# ...no weblink L'Apartment 11213
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11213
# 11213  results: 4  - 286
# timeout/error 90037 287
# ...no weblink B Hemmings & Co. 48197
# 48197  results: 1  - 288
# https://elysewalker.com/
# 94538  results: 1  - 289
# https://marissacollections.com/
# ...no weblink Marissa Collections 33157
# 33157  results: 2  - 290
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92703  results: 4  - 291
# https://elysewalker.com/
# 89115  results: 1  - 292
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 89121  results: 4  - 293
# https://elysewalker.com/
# 94541  results: 1  - 294
# 99654  results: 0  - 295
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90022  results: 4  - 296
# ...no weblink Capitol 30331
# 30331  results: 1  - 297
# https://elysewalker.com/
# 95758  results: 1  - 298
# 78251  results: 0  - 299
# 32218  results: 0  - 300
# 85308  results: 0  - 301
# ...no weblink L'Apartment 20019
# https://elysewalker.com/
# https://fivestoryny.com/
# 20019  results: 3  - 302
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92801  results: 4  - 303
# 66061  results: 0  - 304
# https://elysewalker.com/
# 95206  results: 1  - 305
# 43081  results: 0  - 306
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92677  results: 4  - 307
# timeout/error 94513 308
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91343  results: 4  - 309
# 23322  results: 0  - 310
# https://elysewalker.com/
# 94015  results: 1  - 311
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92562  results: 4  - 312
# ...no weblink L'Apartment 7002
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 7002
# 7002  results: 4  - 313
# ...no weblink L'Apartment 17603
# https://elysewalker.com/
# https://fivestoryny.com/
# 17603  results: 3  - 314
# ...no weblink Forty Five Ten 77072
# ...no weblink Forty Five Ten 77072
# ...no weblink Market Highland Park Village 77072
# 77072  results: 3  - 315
# 60628  results: 0  - 316
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92201  results: 4  - 317
# 38401  results: 0  - 318
# ...no weblink Capitol 29681
# 29681  results: 1  - 319
# ...no weblink L'Apartment 11201
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11201
# 11201  results: 4  - 320
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10027
# ...no weblink VRSNL 10027
# 10027  results: 4  - 321
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 10977
# ...no weblink VRSNL 10977
# 10977  results: 4  - 322
# 85041  results: 0  - 323
# https://elysewalker.com/
# 94501  results: 1  - 324
# 87120  results: 0  - 325
# 85033  results: 0  - 326
# ...no weblink Capitol 28215
# 28215  results: 1  - 327
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 11432
# ...no weblink VRSNL 11432
# 11432  results: 4  - 328
# timeout/error 84404 329
# ...no weblink B Hemmings & Co. 14850
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 14850
# 14850  results: 4  - 330
# ...no weblink Capitol 29072
# 29072  results: 1  - 331
# https://marissacollections.com/
# ...no weblink Marissa Collections 33463
# 33463  results: 2  - 332
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 7093
# ...no weblink VRSNL 7093
# 7093  results: 4  - 333
# 46307  results: 0  - 334
# https://marissacollections.com/
# ...no weblink Marissa Collections 32822
# 32822  results: 2  - 335
# ...no weblink Capitol 28078
# 28078  results: 1  - 336
# 2301  results: 0  - 337
# ...no weblink Capitol 30062
# 30062  results: 1  - 338
# ...no weblink L'Apartment 20147
# https://elysewalker.com/
# https://fivestoryny.com/
# 20147  results: 3  - 339
# ...no weblink Capitol 30188
# 30188  results: 1  - 340
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91762  results: 4  - 341
# https://marissacollections.com/
# ...no weblink Marissa Collections 32765
# 32765  results: 2  - 342
# ...no weblink Forty Five Ten 77346
# ...no weblink Forty Five Ten 77346
# ...no weblink Market Highland Park Village 77346
# 77346  results: 3  - 343
# https://www.amazon.com/
# 98682  results: 1  - 344
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92115  results: 4  - 345
# ...no weblink L'Apartment 8753
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 8753
# 8753  results: 4  - 346
# https://elysewalker.com/
# https://elysewalker.com/
# 93906  results: 2  - 347
# 60651  results: 0  - 348
# ...no weblink Forty Five Ten 78664
# ...no weblink Forty Five Ten 78664
# ...no weblink Market Highland Park Village 78664
# 78664  results: 3  - 349
# timeout/error 94806 350
# ...no weblink L'Apartment 20878
# https://elysewalker.com/
# https://fivestoryny.com/
# 20878  results: 3  - 351
# https://elysewalker.com/
# 95020  results: 1  - 352
# ...no weblink B Hemmings & Co. 44256
# 44256  results: 1  - 353
# 43026  results: 0  - 354
# 85326  results: 0  - 355
# 40475  results: 0  - 356
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92346  results: 4  - 357
# ...no weblink Forty Five Ten 78745
# ...no weblink Forty Five Ten 78745
# ...no weblink Market Highland Park Village 78745
# 78745  results: 3  - 358
# 60657  results: 0  - 359
# ...no weblink L'Apartment 20906
# https://elysewalker.com/
# https://fivestoryny.com/
# 20906  results: 3  - 360
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10463
# ...no weblink VRSNL 10463
# 10463  results: 4  - 361
# 80015  results: 0  - 362
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 6902
# ...no weblink VRSNL 6902
# 6902  results: 4  - 363
# ...no weblink Capitol 28277
# 28277  results: 1  - 364
# ...no weblink L'Apartment 19720
# https://elysewalker.com/
# https://fivestoryny.com/
# 19720  results: 3  - 365
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10024
# ...no weblink VRSNL 10024
# 10024  results: 4  - 366
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91977  results: 4  - 367
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92404  results: 4  - 368
# https://elysewalker.com/
# 95127  results: 1  - 369
# ...no weblink B Hemmings & Co. 44035
# 44035  results: 1  - 370
# timeout/error 91770 371
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 11372
# ...no weblink VRSNL 11372
# 11372  results: 4  - 372
# 85008  results: 0  - 373
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 89123  results: 4  - 374
# 78574  results: 0  - 375
# 78250  results: 0  - 376
# https://marissacollections.com/
# ...no weblink Marissa Collections 33313
# 33313  results: 2  - 377
# ...no weblink L'Apartment 19143
# https://elysewalker.com/
# https://fivestoryny.com/
# 19143  results: 3  - 378
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 11717
# ...no weblink VRSNL 11717
# 11717  results: 4  - 379
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90640  results: 4  - 380
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90019  results: 4  - 381
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91950  results: 4  - 382
# ...no weblink Forty Five Ten 75071
# ...no weblink Market Highland Park Village 75071
# ...no weblink Forty Five Ten 75071
# 75071  results: 3  - 383
# ...no weblink Capitol 27406
# 27406  results: 1  - 384
# 60402  results: 0  - 385
# ...no weblink Forty Five Ten 75043
# ...no weblink Forty Five Ten 75043
# ...no weblink Market Highland Park Village 75043
# 75043  results: 3  - 386
# 42101  results: 0  - 387
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92707  results: 4  - 388
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 11434
# ...no weblink VRSNL 11434
# 11434  results: 4  - 389
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90660  results: 4  - 390
# 32210  results: 0  - 391
# timeout/error 92627 392
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92504  results: 4  - 393
# ...no weblink L'Apartment 11210
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 11210
# 11210  results: 4  - 394
# ...no weblink Forty Five Ten 77373
# ...no weblink Forty Five Ten 77373
# ...no weblink Market Highland Park Village 77373
# 77373  results: 3  - 395
# 79928  results: 0  - 396
# https://elysewalker.com/
# 95608  results: 1  - 397
# ...no weblink Forty Five Ten 77396
# ...no weblink Forty Five Ten 77396
# ...no weblink Market Highland Park Village 77396
# 77396  results: 3  - 398
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 10023
# ...no weblink VRSNL 10023
# 10023  results: 4  - 399
# 43055  results: 0  - 400
# 43130  results: 0  - 401
# ...no weblink Forty Five Ten 78640
# ...no weblink Forty Five Ten 78640
# ...no weblink Market Highland Park Village 78640
# 78640  results: 3  - 402
# ...no weblink Forty Five Ten 78240
# 78240  results: 1  - 403
# ...no weblink Forty Five Ten 77077
# ...no weblink Forty Five Ten 77077
# ...no weblink Market Highland Park Village 77077
# 77077  results: 3  - 404
# ...no weblink Forty Five Ten 75150
# ...no weblink Forty Five Ten 75150
# ...no weblink Market Highland Park Village 75150
# 75150  results: 3  - 405
# 60073  results: 0  - 406
# ...no weblink Forty Five Ten 74012
# ...no weblink Market Highland Park Village 74012
# ...no weblink Forty Five Ten 74012
# 74012  results: 3  - 407
# 80634  results: 0  - 408
# ...no weblink Forty Five Ten 78249
# ...no weblink Forty Five Ten 78249
# ...no weblink Market Highland Park Village 78249
# 78249  results: 3  - 409
# https://elysewalker.com/
# https://elysewalker.com/
# 93905  results: 2  - 410
# ...no weblink L'Apartment 19134
# https://elysewalker.com/
# https://fivestoryny.com/
# 19134  results: 3  - 411
# ...no weblink Forty Five Ten 75040
# ...no weblink Market Highland Park Village 75040
# ...no weblink Forty Five Ten 75040
# 75040  results: 3  - 412
# timeout/error 95014 413
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92647  results: 4  - 414
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91702  results: 4  - 415
# 78228  results: 0  - 416
# ...no weblink Forty Five Ten 77407
# ...no weblink Forty Five Ten 77407
# ...no weblink Market Highland Park Village 77407
# 77407  results: 3  - 417
# 60619  results: 0  - 418
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10701
# ...no weblink VRSNL 10701
# 10701  results: 4  - 419
# https://elysewalker.com/
# 94122  results: 1  - 420
# ...no weblink Capitol 30058
# 30058  results: 1  - 421
# ...no weblink Forty Five Ten 73160
# ...no weblink Market Highland Park Village 73160
# ...no weblink Forty Five Ten 73160
# 73160  results: 3  - 422
# 32244  results: 0  - 423
# https://marissacollections.com/
# ...no weblink Marissa Collections 34711
# 34711  results: 2  - 424
# https://elysewalker.com/
# 95111  results: 1  - 425
# 78504  results: 0  - 426
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink L'Apartment 7047
# ...no weblink VRSNL 7047
# 7047  results: 4  - 427
# 37167  results: 0  - 428
# ...no weblink B Hemmings & Co. 48180
# 48180  results: 1  - 429
# 78254  results: 0  - 430
# ...no weblink L'Apartment 10312
# https://elysewalker.com/
# https://fivestoryny.com/
# ...no weblink VRSNL 10312
# 10312  results: 4  - 431
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90004  results: 4  - 432
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91732  results: 4  - 433
# 53215  results: 0  - 434
# https://marissacollections.com/
# ...no weblink Marissa Collections 32818
# 32818  results: 2  - 435
# 37122  results: 0  - 436
# ...no weblink L'Apartment 21740
# https://elysewalker.com/
# https://fivestoryny.com/
# 21740  results: 3  - 437
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 91761  results: 4  - 438
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90731  results: 4  - 439
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92630  results: 4  - 440
# 2360  results: 0  - 441
# 30263  results: 0  - 442
# 2148  results: 0  - 443
# ...no weblink Forty Five Ten 77521
# ...no weblink Forty Five Ten 77521
# ...no weblink Market Highland Park Village 77521
# 77521  results: 3  - 444
# ...no weblink Forty Five Ten 75227
# ...no weblink Forty Five Ten 75227
# ...no weblink Market Highland Park Village 75227
# 75227  results: 3  - 445
# https://marissacollections.com/
# ...no weblink Marissa Collections 34744
# 34744  results: 2  - 446
# ...no weblink Capitol 29445
# 29445  results: 1  - 447
# https://elysewalker.com/
# 95051  results: 1  - 448
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 93312  results: 4  - 449
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92057  results: 4  - 450
# ...no weblink Capitol 28314
# 28314  results: 1  - 451
# https://elysewalker.com/
# 95828  results: 1  - 452
# https://marissacollections.com/
# ...no weblink Marissa Collections 33458
# 33458  results: 2  - 453
# 72401  results: 0  - 454
# timeout/error 30144 455
# ...no weblink Capitol 30083
# 30083  results: 1  - 456
# ...no weblink Marissa Collections 33511
# https://marissacollections.com/
# 33511  results: 2  - 457
# https://marissacollections.com/
# ...no weblink Marissa Collections 33142
# 33142  results: 2  - 458
# ...no weblink Forty Five Ten 77840
# ...no weblink Forty Five Ten 77840
# ...no weblink Market Highland Park Village 77840
# 77840  results: 3  - 459
# ...no weblink Forty Five Ten 75056
# ...no weblink Market Highland Park Village 75056
# ...no weblink Forty Five Ten 75056
# 75056  results: 3  - 460
# 956  results: 0  - 461
# 60609  results: 0  - 462
# 2155  results: 0  - 463
# 37129  results: 0  - 464
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 90042  results: 4  - 465
# https://marissacollections.com/
# ...no weblink Marissa Collections 33414
# 33414  results: 2  - 466
# https://marissacollections.com/
# ...no weblink Marissa Collections 32808
# 32808  results: 2  - 467
# 83709  results: 0  - 468
# ...no weblink Capitol 29485
# 29485  results: 1  - 469
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92570  results: 4  - 470
# https://marissacollections.com/
# ...no weblink Marissa Collections 33125
# 33125  results: 2  - 471
# 78501  results: 0  - 472
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10031
# ...no weblink VRSNL 10031
# 10031  results: 4  - 473
# timeout/error 37064 474
# timeout/error 20874 475
# https://marissacollections.com/
# ...no weblink Marissa Collections 32825
# 32825  results: 2  - 476
# ...no weblink Forty Five Ten 77386
# ...no weblink Forty Five Ten 77386
# ...no weblink Market Highland Park Village 77386
# 77386  results: 3  - 477
# ...no weblink L'Apartment 22030
# https://elysewalker.com/
# https://fivestoryny.com/
# 22030  results: 3  - 478
# ...no weblink Capitol 30906
# 30906  results: 1  - 479
# ...no weblink Forty Five Ten 77375
# ...no weblink Forty Five Ten 77375
# ...no weblink Market Highland Park Village 77375
# 77375  results: 3  - 480
# 72712  results: 0  - 481
# 85122  results: 0  - 482
# 6010  results: 0  - 483
# 37128  results: 0  - 484
# ...no weblink Forty Five Ten 78753
# ...no weblink Forty Five Ten 78753
# ...no weblink Market Highland Park Village 78753
# 78753  results: 3  - 485
# ...no weblink Forty Five Ten 76137
# ...no weblink Forty Five Ten 76137
# ...no weblink Market Highland Park Village 76137
# 76137  results: 3  - 486
# https://elysewalker.com/
# 95112  results: 1  - 487
# https://marissacollections.com/
# ...no weblink Marissa Collections 33064
# 33064  results: 2  - 488
# 96818  results: 0  - 489
# ...no weblink B Hemmings & Co. 44060
# 44060  results: 1  - 490
# 43230  results: 0  - 491
# https://elysewalker.com/
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# 93030  results: 4  - 492
# 79924  results: 0  - 493
# 22407  results: 0  - 494
# https://fivestoryny.com/
# https://elysewalker.com/
# ...no weblink L'Apartment 10032
# ...no weblink VRSNL 10032
# 10032  results: 4  - 495
# timeout/error 76010 496
# https://elysewalker.com/
# http://shop-capitol.com/
# https://elysewalker.com/
# https://elysewalker.com/
# 92571  results: 4  - 497
# ...no weblink L'Apartment 22192
# https://elysewalker.com/
# https://fivestoryny.com/
# 22192  results: 3  - 498
# ...no weblink L'Apartment 21122
# https://elysewalker.com/
# https://fivestoryny.com/
# 21122  results: 3  - 499
# ...no weblink L'Apartment 21117
# https://elysewalker.com/
# https://fivestoryny.com/
# 21117  results: 3  - 500
# 60016  results: 0  - 501
# lespecs
# ...no weblink Heidi Says 94123
# https://www.urbanoutfitters.com/
# ...no weblink Two Birds 94123
# ...no weblink Style Typology 94123
# http://wearegoodstock.com/defaultsite
# ...no weblink Eyewear Love Affair 94123
# ...no weblink Good Neighbor 94123
# http://www.intermixonline.com/
# ...no weblink Muse 94123
# https://fever-boutique-womens-clothing-store.business.site/?utm_source=gmb&utm_medium=referral
# 94123  results: 10  - 1
# ...no weblink Egan Philadelphia 19104
# https://www.southmoonunder.com/
# https://www.shop-kin.com/
# https://threadstheshop.com/
# ...no weblink Threads on Main 19104
# http://maxwelljamesjeans.com/
# ...no weblink Maxwell James 19104
# https://www.southmoonunder.com/
# ...no weblink Everything But Water 19104
# https://www.southmoonunder.com/
# 19104  results: 10  - 2
# 77494  results: 0  - 3
# https://707street.com/collections/women
# ...no weblink Show Me Your Mumu 90011
# ...no weblink Le Box Blanc 90011
# ...no weblink Livelife Worldwide 90011
# ...no weblink No Season 90011
# ...no weblink The Standard Hotel 90011
# ...no weblink Snoangel 90011
# ...no weblink Clare V 90011
# ...no weblink American Rag 90011
# ...no weblink Arora Boheme 90011
# ...no weblink Fairfax Optical Lab 90011
# ...no weblink Homecoming Honolulu 90011
# ...no weblink Fashionpass Inc. 90011
# http://www.intermixonline.com/
# https://kith.com/
# https://kith.com/
# http://www.intermixonline.com/
# ...no weblink The Lady And The Sailor 90011
# ...no weblink Crown J Collection 90011
# ...no weblink Elisa B 90011
# ...no weblink Lust Covet Desire 90011
# ...no weblink Madison 90011
# ...no weblink Spyder 90011
# ...no weblink Turquoise 90011
# ...no weblink Wheat Boutique 90011
# https://www.everythingbutwater.com/
# ...no weblink Mercenary General Store 90011
# https://www.beautytreatsspa.com/
# 90011  results: 28  - 4
# ...no weblink Omni - Frisco Silver Star 75034
# https://www.dillards.com/
# http://www.evereve.com/
# https://www.everythingbutwater.com/
# 75034  results: 4  - 5
# ...no weblink The Silver Room 60629
# http://www.capsulechicago.com/
# http://www.evereve.com/
# http://www.intermixonline.com/
# ...no weblink Wayward - Chicago 60629
# ...no weblink Felt 60629
# ...no weblink May & March 60629
# http://www.mayandmarch.com/
# http://www.evereve.com/
# http://www.evereve.com/
# http://www.evereve.com/
# http://www.evereve.com/
# ...no weblink Maxine 60629
# 60629  results: 13  - 6
# https://www.facebook.com/driggsmercantile/
# ...no weblink Friends NY 11211
# ...no weblink Red Pearl 11211
# ...no weblink Swords-Smith 11211
# https://swords-smith.com/
# http://n/A
# http://www.theoryofgaia.com/
# ...no weblink Theory Of Gaia 11211
# ...no weblink Blue & Cream 11211
# http://-/
# ...no weblink Trade @ Public Hotel (Trade) 11211
# https://kith.com/
# https://kith.com/
# https://kith.com/
# http://www.frenchcornernyc.com/
# http://www.intermixonline.com/
# http://www.intermixonline.com/
# ...no weblink Todd Snyder (American Eagle) 11211
# https://www.toddsnyder.com/
# https://www.veronicabeard.com/shop/new-arrivals/?gclid=Cj0KCQjwn-bWBRDGARIsAPS1svuQd8eTl0jnHnb3EX1SlMUqjInfuPO2fLzfuFaL24nT3sPo_J9pPpUaAtSrEALw_wcB&gclsrc=aw.ds
# https://veronicabeard.com/
# ...no weblink Cloak Supply 11211
# ...no weblink New York Glass 11211
# ...no weblink Imwim 11211
# https://www.modaoperandi.com/women
# https://www.urbanoutfitters.com/
# https://www.modaoperandi.com/women
# https://www.urbanoutfitters.com/
# ...no weblink Edon Manor 11211
# http://www.intermixonline.com/
# http://www.ultimatespectacle.com/
# http://www.intermixonline.com/
# http://-/
# ...no weblink Phluid Project 11211
# ...no weblink The Standard Hotel 11211
# http://www.fivestoryny.com/
# ...no weblink Atelier Fashion 11211
# ...no weblink Cosmos Eye Care 11211
# https://www.cosmoseyecare.com/
# http://www.intermixonline.com/
# https://www.everythingbutwater.com/
# ...no weblink The Brass Owl 11211
# http://www.thebrassowl.com/
# ...no weblink Work It Out 11211
# ...no weblink Blue Stone Stores 11211
# ...no weblink Brooke & Bel 11211
# ...no weblink Kennedy Department Store 11211
# ...no weblink Harlem Vista Site Eyecare 11211
# ...no weblink Cohens Fashion Optical 11211
# ...no weblink Bright Eyes Optical 11211
# ...no weblink Lester's Of New York Inc 11211
# ...no weblink Tribeca Fashion House 11211
# ...no weblink Marcia's Attic 11211
# http://marciasattic.com/
# http://www.clemintineny.com/
# ...no weblink Optical Elegance 11211
# https://www.everythingbutwater.com/
# http://www.intermixonline.com/
# 11211  results: 58  - 7
# https://www.everythingbutwater.com/
# 77449  results: 1  - 8
# ...no weblink Omni - Frisco Silver Star 75070
# https://www.everythingbutwater.com/
# https://www.dillards.com/
# http://www.evereve.com/
# https://www.dillards.com/
# 75070  results: 5  - 9
# ...no weblink GAL 79936
# 79936  results: 1  - 10
# ...no weblink Cosmos Eye Care 11368
# https://www.cosmoseyecare.com/
# ...no weblink The Brass Owl 11368
# http://www.thebrassowl.com/
# ...no weblink Friends NY 11368
# https://www.facebook.com/driggsmercantile/
# https://www.everythingbutwater.com/
# http://www.intermixonline.com/
# ...no weblink Red Pearl 11368
# http://www.ultimatespectacle.com/
# http://www.fivestoryny.com/
# ...no weblink Harlem Vista Site Eyecare 11368
# ...no weblink Swords-Smith 11368
# https://swords-smith.com/
# ...no weblink Cohens Fashion Optical 11368
# http://www.frenchcornernyc.com/
# ...no weblink Imwim 11368
# http://n/A
# ...no weblink Todd Snyder (American Eagle) 11368
# https://www.toddsnyder.com/
# ...
# http://n/A
# ...no weblink Phluid Project 10701
# http://-/
# ...no weblink The Standard Hotel 10701
# 10701  results: 39  - 419
# ...no weblink Two Birds 94122
# ...no weblink Heidi Says 94122
# https://www.urbanoutfitters.com/
# ...no weblink Style Typology 94122
# http://www.intermixonline.com/
# http://wearegoodstock.com/defaultsite
# ...no weblink Eyewear Love Affair 94122
# ...no weblink Good Neighbor 94122
# ...no weblink Muse 94122
# 94122  results: 9  - 420
# https://select-shades.com/?v=400b9db48e62
# 30058  results: 1  - 421
# ...no weblink Omni Okc 73160
# https://www.dillards.com/
# http://www.evereve.com/
# ...no weblink Rosegold Apparel 73160
# 73160  results: 4  - 422
# ...no weblink Emory Clothing 32244
# https://www.dillards.com/
# 32244  results: 2  - 423
# ...no weblink Stitch & Arrow 34711
# 34711  results: 1  - 424
# 95111  results: 0  - 425
# 78504  results: 0  - 426
# 7047  results: 0  - 427
# ...no weblink Ali + Mi 37167
# 37167  results: 1  - 428
# ...no weblink Envy Boutique 48180
# 48180  results: 1  - 429
# https://www.dillards.com/
# https://www.everythingbutwater.com/
# https://www.neimanmarcus.com/
# 78254  results: 3  - 430
# ...no weblink Tribeca Fashion House 10312
# ...no weblink Bright Eyes Optical 10312
# ...no weblink Glue Miranda 10312
# ...no weblink Lester's Of New York Inc 10312
# ...no weblink Blue Stone Stores 10312
# https://kith.com/
# https://www.facebook.com/Sorellabellanjboutique/
# ...no weblink Brooke & Bel 10312
# http://www.intermixonline.com/
# ...no weblink Kennedy Department Store 10312
# https://www.modaoperandi.com/women
# https://www.modaoperandi.com/women
# ...no weblink New York Glass 10312
# ...no weblink Optical Elegance 10312
# http://-/
# ...no weblink Trade @ Public Hotel (Trade) 10312
# https://www.veronicabeard.com/shop/new-arrivals/?gclid=Cj0KCQjwn-bWBRDGARIsAPS1svuQd8eTl0jnHnb3EX1SlMUqjInfuPO2fLzfuFaL24nT3sPo_J9pPpUaAtSrEALw_wcB&gclsrc=aw.ds
# https://veronicabeard.com/
# ...no weblink Work It Out 10312
# 10312  results: 19  - 431
# ...no weblink Snoangel 90004
# ...no weblink American Rag 90004
# ...no weblink Fairfax Optical Lab 90004
# ...no weblink Le Box Blanc 90004
# ...no weblink The Standard Hotel 90004
# https://kith.com/
# ...no weblink Livelife Worldwide 90004
# ...no weblink Arora Boheme 90004
# https://kith.com/
# http://www.intermixonline.com/
# ...no weblink No Season 90004
# ...no weblink Clare V 90004
# https://707street.com/collections/women
# ...no weblink The Lady And The Sailor 90004
# http://www.intermixonline.com/
# ...no weblink Show Me Your Mumu 90004
# ...no weblink Madison 90004
# ...no weblink Homecoming Honolulu 90004
# ...no weblink Elisa B 90004
# https://www.everythingbutwater.com/
# ...no weblink Lust Covet Desire 90004
# ...no weblink Mercenary General Store 90004
# ...no weblink Wheat Boutique 90004
# ...no weblink Crown J Collection 90004
# ...no weblink Fashionpass Inc. 90004
# ...no weblink Spyder 90004
# 90004  results: 26  - 432
# ...no weblink Crown J Collection 91732
# ...no weblink Elisa B 91732
# ...no weblink Show Me Your Mumu 91732
# ...no weblink Clare V 91732
# ...no weblink Everything But Water 91732
# https://707street.com/collections/women
# ...no weblink Livelife Worldwide 91732
# ...no weblink No Season 91732
# ...no weblink The Standard Hotel 91732
# ...no weblink Arora Boheme 91732
# ...no weblink Le Box Blanc 91732
# 91732  results: 11  - 433
# http://www.evereve.com/
# ...no weblink Offline By Aerie 53215
# http://www.evereve.com/
# http://www.evereve.com/
# 53215  results: 4  - 434
# ...no weblink Stitch & Arrow 32818
# 32818  results: 1  - 435
# 37122  results: 0  - 436
# 21740  results: 0  - 437
# 91761  results: 0  - 438
# ...no weblink Turquoise 90731
# ...no weblink PRISM Boutique 90731
# https://www.beautytreatsspa.com/
# ...no weblink Fashionpass Inc. 90731
# ...no weblink Spyder 90731
# ...no weblink Stitch And Feather 90731
# ...no weblink Homecoming Honolulu 90731
# 90731  results: 7  - 439
# ...no weblink Brigade La 92630
# https://www.tillys.com/
# ...no weblink Everything But Water 92630
# ...no weblink Amenah 92630
# ...no weblink Landmark Surf 92630
# ...no weblink Piajeh Boutique 92630
# ...no weblink Blue Eyed Girl 92630
# https://hjom.com/pages/contact
# 92630  results: 8  - 440
# timeout/error 2360 441
# 30263  results: 0  - 442
# 2148  results: 0  - 443
# 77521  results: 0  - 444
# ...no weblink Neighborhood Goods 75227
# ...no weblink Omni Dallas Hotel 75227
# https://www.everythingbutwater.com/
# ...no weblink Omni La Costa,LLC - Dallas 75227
# ...no weblink Cabana 75227
# ...no weblink St Bernard Sports 75227
# https://www.dillards.com/
# 75227  results: 7  - 445
# 34744  results: 0  - 446
# ...no weblink Ii Brunettes 29445
# https://www.instagram.com/harperhartfordboutique/?hl=en
# ...no weblink Beau & Ro 29445
# https://hampdenclothing.com/
# https://hampdenclothing.com/
# ...no weblink Style Exchange 29445
# https://shopsxc.com/password
# ...no weblink Two Cumberland 29445
# 29445  results: 8  - 447
# ...no weblink Ifchic 95051
# 95051  results: 1  - 448
# https://edayspas.com/
# 93312  results: 1  - 449
# https://jaydenp.com/
# http://-/
# 92057  results: 2  - 450
# 28314  results: 0  - 451
# 95828  results: 0  - 452
# ...no weblink Lola Dre 33458
# 33458  results: 1  - 453
# 72401  results: 0  - 454
# https://select-shades.com/?v=400b9db48e63
# ...no weblink Waiting on Martha 30144
# 30144  results: 2  - 455
# https://select-shades.com/?v=400b9db48e62
# https://www.everythingbutwater.com/
# https://www.everythingbutwater.com/
# ...no weblink Ktm Fitness - Sculpthouse 30083
# http://www.shoptulipano.com/
# http://www.evereve.com/
# https://www.southmoonunder.com/
# 30083  results: 7  - 456
# ...no weblink Everything But Water 33511
# https://www.everythingbutwater.com/
# 33511  results: 2  - 457
# ...no weblink Market Boutique 33142
# https://www.normou.com/pages/contact-us
# ...no weblink Blank Cool Hunting Studio (Agrupa S.A./ shop at blank) 33142
# ...no weblink Alter Ego 33142
# ...no weblink The Standard Hotel 33142
# https://www.standardhotels.com/miami/properties/miami-beach
# https://www.jessieboutique.com/
# ...no weblink Menin Hotels (Mondrian Miami) 33142
# http://-/
# http://-/
# ...no weblink The Backroom 33142
# https://kith.com/
# https://kith.com/
# http://-/
# ...no weblink Nautilus Hotel (Parc Fashion) 33142
# https://www.shelborne.com/
# https://www.urbanoutfitters.com/
# ...no weblink Egan Miami (Cadillac Hotel & Beach) 33142
# http://www.intermixonline.com/
# ...no weblink Lovango Island 33142
# http://www.shopsplash.com/
# ...no weblink Splash Boutique 33142
# ...no weblink The Wardrobe 33142
# http://www.intermixonline.com/
# https://www.neimanmarcus.com/
# https://www.everythingbutwater.com/
# http://-/
# http://-/
# 33142  results: 28  - 458
# ...no weblink Hemline 77840
# 77840  results: 1  - 459
# https://www.dillards.com/
# http://www.evereve.com/
# ...no weblink Omni - Frisco Silver Star 75056
# https://www.everythingbutwater.com/
# ...no weblink Omni Mandalay Toc 75056
# http://www.evereve.com/
# 75056  results: 6  - 460
# 956  results: 0  - 461
# ...no weblink The Silver Room 60609
# http://www.intermixonline.com/
# http://www.capsulechicago.com/
# http://www.evereve.com/
# ...no weblink Wayward - Chicago 60609
# ...no weblink May & March 60609
# http://www.mayandmarch.com/
# ...no weblink Felt 60609
# http://www.evereve.com/
# http://www.evereve.com/
# http://www.evereve.com/
# ...no weblink Maxine 60609
# 60609  results: 12  - 462
# 2155  results: 0  - 463
# 37129  results: 0  - 464
# ...no weblink Clare V 90042
# ...no weblink Elisa B 90042
# ...no weblink Arora Boheme 90042
# ...no weblink Crown J Collection 90042
# ...no weblink No Season 90042
# ...no weblink The Standard Hotel 90042
# ...no weblink Livelife Worldwide 90042
# ...no weblink Show Me Your Mumu 90042
# ...no weblink Le Box Blanc 90042
# https://707street.com/collections/women
# ...no weblink Snoangel 90042
# ...no weblink American Rag 90042
# ...no weblink Fairfax Optical Lab 90042
# https://kith.com/
# https://kith.com/
# http://www.intermixonline.com/
# ...no weblink The Lady And The Sailor 90042
# http://www.intermixonline.com/
# ...no weblink Homecoming Honolulu 90042
# 90042  results: 19  - 465
# ...no weblink Bh Naturals 33414
# https://www.everythingbutwater.com/
# ...no weblink Rapunzel's Closet 33414
# ...no weblink Rapunzel's Closet 33414
# ...no weblink The Skinny Dip 33414
# 33414  results: 5  - 466
# ...no weblink Stitch & Arrow 32808
# 32808  results: 1  - 467
# http://www.evereve.com/
# 83709  results: 1  - 468
# 29485  results: 0  - 469
# https://www.outletsatlakeelsinore.com/store/Pacific-Shore-Boardshop/2138787963/
# 92570  results: 1  - 470
# ...no weblink Market Boutique 33125
# https://www.normou.com/pages/contact-us
# ...no weblink Blank Cool Hunting Studio (Agrupa S.A./ shop at blank) 33125
# https://www.standardhotels.com/miami/properties/miami-beach
# ...no weblink The Standard Hotel 33125
# ...no weblink Menin Hotels (Mondrian Miami) 33125
# http://-/
# http://-/
# ...no weblink The Backroom 33125
# https://www.jessieboutique.com/
# http://www.shopsplash.com/
# ...no weblink Splash Boutique 33125
# ...no weblink The Wardrobe 33125
# https://www.urbanoutfitters.com/
# ...no weblink Alter Ego 33125
# http://www.intermixonline.com/
# https://kith.com/
# https://kith.com/
# http://-/
# ...no weblink Nautilus Hotel (Parc Fashion) 33125
# https://www.shelborne.com/
# ...no weblink Egan Miami (Cadillac Hotel & Beach) 33125
# https://www.everythingbutwater.com/
# ...no weblink Lovango Island 33125
# http://www.intermixonline.com/
# https://www.neimanmarcus.com/
# http://-/
# http://-/
# 33125  results: 28  - 471
# 78501  results: 0  - 472
# ...no weblink Cohens Fashion Optical 10031
# ...no weblink Harlem Vista Site Eyecare 10031
# https://www.everythingbutwater.com/
# http://www.intermixonline.com/
# http://www.fivestoryny.com/
# ...no weblink The Brass Owl 10031
# http://www.thebrassowl.com/
# http://www.ultimatespectacle.com/
# ...no weblink Marcia's Attic 10031
# http://marciasattic.com/
# https://www.urbanoutfitters.com/
# ...no weblink Imwim 10031
# https://www.urbanoutfitters.com/
# http://www.frenchcornernyc.com/
# ...no weblink Atelier Fashion 10031
# ...no weblink Todd Snyder (American Eagle) 10031
# https://www.toddsnyder.com/
# http://www.intermixonline.com/
# ...no weblink Phluid Project 10031
# ...no weblink Cloak Supply 10031
# ...no weblink Cosmos Eye Care 10031
# https://www.cosmoseyecare.com/
# ...no weblink Edon Manor 10031
# http://www.intermixonline.com/
# http://www.intermixonline.com/
# http://n/A
# http://-/
# ...no weblink The Standard Hotel 10031
# ...no weblink Blue & Cream 10031
# ...no weblink Brooke & Bel 10031
# https://www.facebook.com/driggsmercantile/
# http://www.intermixonline.com/
# ...no weblink Kennedy Department Store 10031
# https://kith.com/
# https://kith.com/
# https://www.modaoperandi.com/women
# https://www.modaoperandi.com/women
# ...no weblink New York Glass 10031
# ...no weblink Red Pearl 10031
# http://www.theoryofgaia.com/
# ...no weblink Theory Of Gaia 10031
# http://-/
# ...no weblink Trade @ Public Hotel (Trade) 10031
# https://www.veronicabeard.com/shop/new-arrivals/?gclid=Cj0KCQjwn-bWBRDGARIsAPS1svuQd8eTl0jnHnb3EX1SlMUqjInfuPO2fLzfuFaL24nT3sPo_J9pPpUaAtSrEALw_wcB&gclsrc=aw.ds
# https://veronicabeard.com/
# ...no weblink Work It Out 10031
# ...no weblink Swords-Smith 10031
# https://swords-smith.com/
# https://www.everythingbutwater.com/
# ...no weblink Friends NY 10031
# https://kith.com/
# ...no weblink Blue Stone Stores 10031
# ...no weblink Nouvelle 10031
# ...no weblink Optical Elegance 10031
# http://www.intermixonline.com/
# ...no weblink Bright Eyes Optical 10031
# 10031  results: 56  - 473
# http://www.evereve.com/
# ...no weblink Offline By Aerie 37064
# ...no weblink Ali + Mi 37064
# http://www.everalicestudio.com/
# http://www.evereve.com/
# ...no weblink Everything But Water 37064
# 37064  results: 6  - 474
# https://www.southmoonunder.com/
# 20874  results: 1  - 475
# 32825  results: 0  - 476
# 77386  results: 0  - 477
# https://www.southmoonunder.com/
# https://bishopboutique.com/
# http://www.intermixonline.com/
# https://www.southmoonunder.com/
# https://www.tnuck.com/
# 22030  results: 5  - 478
# 30906  results: 0  - 479
# 77375  results: 0  - 480
# ...no weblink Label Boutique 72712
# 72712  results: 1  - 481
# 85122  results: 0  - 482
# 6010  results: 0  - 483
# 37128  results: 0  - 484
# http://www.evereve.com/
# https://www.neimanmarcus.com/
# ...no weblink C. Jane 78753
# ...no weblink Estilo 78753
# ...no weblink Olive 78753
# ...no weblink Valentines 78753
# ...no weblink Cove 78753
# ...no weblink Collings Outfitters LLC 78753
# https://honeyandhay.com/
# ...no weblink Omni Barton Creek - Barton 78753
# https://luxroxboutique.com/
# 78753  results: 11  - 485
# ...no weblink Birdie And James 76137
# https://www.dillards.com/
# http://www.evereve.com/
# https://www.dillards.com/
# https://www.dillards.com/
# ...no weblink Everything But Water 76137
# http://www.evereve.com/
# 76137  results: 7  - 486
# ...no weblink Ifchic 95112
# 95112  results: 1  - 487
# ...no weblink Etiquette - Fl 33064
# ...no weblink Periwinkle 33064
# ...no weblink Periwinkle 33064
# 33064  results: 3  - 488
# ...no weblink Splash Hawaii 96818
# https://www.ripcurl.com/us/
# https://www.ripcurl.com/us/
# https://www.urbanoutfitters.com/
# https://www.urbanoutfitters.com/
# 96818  results: 5  - 489
# http://www.evereve.com/
# 44060  results: 1  - 490
# http://www.evereve.com/
# https://www.truluck.shop/
# http://ladybirdfashion.com/
# http://www.evereve.com/
# ...no weblink Offline By Aerie 43230
# ...no weblink Thread 43230
# 43230  results: 6  - 491
# https://www.ripcurl.com/us/
# 93030  results: 1  - 492
# ...no weblink GAL 79924
# 79924  results: 1  - 493
# 22407  results: 0  - 494
# ...no weblink Harlem Vista Site Eyecare 10032
# ...no weblink Cohens Fashion Optical 10032
# https://www.everythingbutwater.com/
# http://www.intermixonline.com/
# ...no weblink Marcia's Attic 10032
# http://marciasattic.com/
# http://www.fivestoryny.com/
# ...no weblink The Brass Owl 10032
# http://www.thebrassowl.com/
# http://www.ultimatespectacle.com/
# https://www.urbanoutfitters.com/
# ...no weblink Imwim 10032
# https://www.urbanoutfitters.com/
# http://www.frenchcornernyc.com/
# ...no weblink Atelier Fashion 10032
# ...no weblink Cosmos Eye Care 10032
# https://www.cosmoseyecare.com/
# http://www.intermixonline.com/
# ...no weblink Phluid Project 10032
# ...no weblink Todd Snyder (American Eagle) 10032
# https://www.toddsnyder.com/
# ...no weblink Brooke & Bel 10032
# ...no weblink Cloak Supply 10032
# ...no weblink Edon Manor 10032
# http://www.intermixonline.com/
# http://www.intermixonline.com/
# http://n/A
# http://-/
# ...no weblink The Standard Hotel 10032
# ...no weblink Blue & Cream 10032
# https://www.facebook.com/driggsmercantile/
# http://www.intermixonline.com/
# ...no weblink Kennedy Department Store 10032
# https://kith.com/
# https://kith.com/
# https://www.modaoperandi.com/women
# https://www.modaoperandi.com/women
# ...no weblink New York Glass 10032
# ...no weblink Red Pearl 10032
# http://www.theoryofgaia.com/
# ...no weblink Theory Of Gaia 10032
# http://-/
# ...no weblink Trade @ Public Hotel (Trade) 10032
# https://www.veronicabeard.com/shop/new-arrivals/?gclid=Cj0KCQjwn-bWBRDGARIsAPS1svuQd8eTl0jnHnb3EX1SlMUqjInfuPO2fLzfuFaL24nT3sPo_J9pPpUaAtSrEALw_wcB&gclsrc=aw.ds
# https://veronicabeard.com/
# ...no weblink Work It Out 10032
# https://www.everythingbutwater.com/
# ...no weblink Friends NY 10032
# ...no weblink Swords-Smith 10032
# https://swords-smith.com/
# https://kith.com/
# ...no weblink Blue Stone Stores 10032
# ...no weblink Nouvelle 10032
# http://www.intermixonline.com/
# ...no weblink Optical Elegance 10032
# 10032  results: 55  - 495
# https://www.dillards.com/
# https://www.dillards.com/
# ...no weblink Omni Mandalay Toc 76010
# ...no weblink St Bernard Sports 76010
# http://www.evereve.com/
# ...no weblink Everything But Water 76010
# 76010  results: 6  - 496
# https://www.outletsatlakeelsinore.com/store/Pacific-Shore-Boardshop/2138787963/
# 92571  results: 1  - 497
# 22192  results: 0  - 498
# 21122  results: 0  - 499
# http://www.rainadawn.com/
# https://masonmayes.com/
# https://www.southmoonunder.com/
# http://ruthshawinc.com/
# 21117  results: 4  - 500
# http://www.evereve.com/
# ...no weblink Everything But Water 60016
# http://www.evereve.com/
# ...no weblink Maxine 60016
# http://www.evereve.com/
# http://www.evereve.com/
# ...no weblink Felt 60016
# http://www.evereve.com/
# http://www.evereve.com/
# http://www.evereve.com/
# ...no weblink Wayward - Chicago 60016
# ...no weblink May & March 60016
# http://www.mayandmarch.com/
# ...no weblink Von Maur 60016
# 60016  results: 14  - 501
# ===Done===

# %%
# write data to CSV file
with open('mark_lespecs.csv', mode='w', newline='') as file:
    fieldnames = list(resultsList[0].keys())
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    for row in resultsList:
        writer.writerow(row)

# %% [markdown]
# ### Convert to a CSV

# %%
'''

##Write to a JSON
jsonName = 'GreatEight' + str(len(results))
with open(jsonName+".json", "w") as output:
    output.write(json.dumps(results,indent=4)) #dump string
print("===Done===")




##Import a JSON
imported_results = json.load(open(jsonName+'.json'))

##Write JSON to CSV
with open(jsonName+".csv", "w", newline="") as csvfile:
    # create a CSV writer
    writer = csv.writer(csvfile)

    # write the header row
    writer.writerow(["Zipcode", "Name", "Address", "Distance"])

    # write the data rows
    for zipcode, restaurants in imported_results.items():
        for restaurant in restaurants:
            name = restaurant["name"]
            address = restaurant["address"]
            distance = restaurant["distance"]
            writer.writerow([zipcode, name, address, distance])
'''
# Out:
# '\n\n##Write to a JSON\njsonName = \'GreatEight\' + str(len(results))\nwith open(jsonName+".json", "w") as output:\n    output.write(json.dumps(results,indent=4)) #dump string\nprint("===Done===")\n\n\n\n\n##Import a JSON\nimported_results = json.load(open(jsonName+\'.json\'))\n\n##Write JSON to CSV\nwith open(jsonName+".csv", "w", newline="") as csvfile:\n    # create a CSV writer\n    writer = csv.writer(csvfile)\n\n    # write the header row\n    writer.writerow(["Zipcode", "Name", "Address", "Distance"])\n\n    # write the data rows\n    for zipcode, restaurants in imported_results.items():\n        for restaurant in restaurants:\n            name = restaurant["name"]\n            address = restaurant["address"]\n            distance = restaurant["distance"]\n            writer.writerow([zipcode, name, address, distance])\n'
